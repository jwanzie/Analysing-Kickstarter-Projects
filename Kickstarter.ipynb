# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
df = pd.read_csv('ks-projects-201612.csv', encoding = 'latin-1')
# Out:
# /var/folders/bd/dktt89416b95w0mckdnfqm0w0000gn/T/ipykernel_5529/3917055923.py:1: DtypeWarning: Columns (0: Unnamed: 13, 1: Unnamed: 14, 2: Unnamed: 15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ks-projects-201612.csv', encoding = 'latin-1')

# %%
df
# Out:
#                ID                                               name   \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000004038                                     Where is Hank?
# 2       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3       1000011046  Community Film Project: The Art of Neighborhoo...
# 4       1000014025                               Monarch Espresso Bar
# ...            ...                                                ...
# 323745   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 323746   999977640                                          The Tribe
# 323747   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 323748   999987933                           BioDefense Education Kit
# 323749   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#               category  main_category  currency             deadline   goal   \
# 0                Poetry     Publishing       GBP  2015-10-09 11:36:00   1000
# 1        Narrative Film   Film & Video       USD  2013-02-26 00:20:50  45000
# 2                 Music          Music       USD  2012-04-16 04:24:11   5000
# 3          Film & Video   Film & Video       USD  2015-08-29 01:00:00  19500
# 4           Restaurants           Food       USD  2016-04-01 13:38:27  50000
# ...                 ...            ...       ...                  ...    ...
# 323745      Documentary   Film & Video       USD  2014-10-17 02:35:30  50000
# 323746   Narrative Film   Film & Video       USD  2011-07-19 03:35:14   1500
# 323747   Narrative Film   Film & Video       USD  2010-08-16 05:59:00  15000
# 323748       Technology     Technology       USD  2016-02-13 02:00:00  15000
# 323749  Performance Art            Art       USD  2011-08-16 09:07:47   2000
#
#                   launched  pledged       state  backers  country   \
# 0       2015-08-11 12:12:28        0      failed        0       GB
# 1       2013-01-12 00:20:50      220      failed        3       US
# 2       2012-03-17 03:24:11        1      failed        1       US
# 3       2015-07-04 08:35:03     1283    canceled       14       US
# 4       2016-02-26 13:38:27    52375  successful      224       US
# ...                     ...      ...         ...      ...      ...
# 323745  2014-09-17 02:35:30       25    canceled        1       US
# 323746  2011-06-22 03:35:14      155      failed        5       US
# 323747  2010-07-01 19:40:30       20      failed        1       US
# 323748  2016-01-13 18:13:53      200      failed        6       US
# 323749  2011-07-19 09:07:47      524      failed       17       US
#
#        usd pledged  Unnamed: 13 Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0                 0         NaN         NaN         NaN          NaN
# 1               220         NaN         NaN         NaN          NaN
# 2                 1         NaN         NaN         NaN          NaN
# 3              1283         NaN         NaN         NaN          NaN
# 4             52375         NaN         NaN         NaN          NaN
# ...             ...         ...         ...         ...          ...
# 323745           25         NaN         NaN         NaN          NaN
# 323746          155         NaN         NaN         NaN          NaN
# 323747           20         NaN         NaN         NaN          NaN
# 323748          200         NaN         NaN         NaN          NaN
# 323749          524         NaN         NaN         NaN          NaN
#
# [323750 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 323750 entries, 0 to 323749
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              323750 non-null  int64
#  1   name            323746 non-null  str
#  2   category        323745 non-null  str
#  3   main_category   323750 non-null  str
#  4   currency        323750 non-null  str
#  5   deadline        323750 non-null  str
#  6   goal            323750 non-null  str
#  7   launched        323750 non-null  str
#  8   pledged         323750 non-null  str
#  9   state           323750 non-null  str
#  10  backers         323750 non-null  str
#  11  country         323750 non-null  str
#  12  usd pledged     319960 non-null  str
#  13  Unnamed: 13     625 non-null     object
#  14  Unnamed: 14     12 non-null      object
#  15  Unnamed: 15     4 non-null       object
#  16  Unnamed: 16     1 non-null       float64
# dtypes: float64(1), int64(1), object(3), str(12)
# memory usage: 42.0+ MB

# %%
df.head()
# Out:
#           ID                                               name   \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000004038                                     Where is Hank?
# 2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4  1000014025                               Monarch Espresso Bar
#
#         category  main_category  currency             deadline   goal   \
# 0          Poetry     Publishing       GBP  2015-10-09 11:36:00   1000
# 1  Narrative Film   Film & Video       USD  2013-02-26 00:20:50  45000
# 2           Music          Music       USD  2012-04-16 04:24:11   5000
# 3    Film & Video   Film & Video       USD  2015-08-29 01:00:00  19500
# 4     Restaurants           Food       USD  2016-04-01 13:38:27  50000
#
#              launched  pledged       state  backers  country  usd pledged   \
# 0  2015-08-11 12:12:28        0      failed        0       GB            0
# 1  2013-01-12 00:20:50      220      failed        3       US          220
# 2  2012-03-17 03:24:11        1      failed        1       US            1
# 3  2015-07-04 08:35:03     1283    canceled       14       US         1283
# 4  2016-02-26 13:38:27    52375  successful      224       US        52375
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN          NaN

# %%
df.columns
# Out:
# Index(['ID ', 'name ', 'category ', 'main_category ', 'currency ', 'deadline ',
#        'goal ', 'launched ', 'pledged ', 'state ', 'backers ', 'country ',
#        'usd pledged ', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16'],
#       dtype='str')

# %%
df.shape
# Out:
# (323750, 17)

# %%
df.dtypes
# Out:
# ID                  int64
# name                  str
# category              str
# main_category         str
# currency              str
# deadline              str
# goal                  str
# launched              str
# pledged               str
# state                 str
# backers               str
# country               str
# usd pledged           str
# Unnamed: 13        object
# Unnamed: 14        object
# Unnamed: 15        object
# Unnamed: 16       float64
# dtype: object

# %%
print(repr(df.columns[0]))
# Out:
# 'ID '

# %%
df.isnull().sum()
# Out:
# ID                     0
# name                   4
# category               5
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         3790
# Unnamed: 13       323125
# Unnamed: 14       323738
# Unnamed: 15       323746
# Unnamed: 16       323749
# dtype: int64

# %%
df.drop(columns = ['Unnamed: 13','Unnamed: 16'], inplace = True)

# %%
df.drop(columns = ['Unnamed: 14', 'Unnamed: 15'], inplace = True)

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_').str.strip('_')

# %%
df[df['name'].isnull()]
# Out:
#                 ID name        category main_category currency  \
# 142830  1848699072  NaN  Narrative Film  Film & Video      USD
# 262901   634871725  NaN     Video Games         Games      GBP
# 265251   648853978  NaN  Product Design        Design      USD
# 289847   796533179  NaN        Painting           Art      USD
#
#                    deadline    goal             launched pledged      state  \
# 142830  2012-02-29 15:04:00  200000  2012-01-01 12:35:31     100     failed
# 262901  2013-01-06 23:00:00    2000  2012-12-19 23:57:48     196     failed
# 265251  2016-07-18 05:01:47    2500  2016-06-18 05:01:47       0  suspended
# 289847  2011-12-05 05:59:00   35000  2011-11-06 23:55:55     220     failed
#
#        backers country  usd_pledged
# 142830       1      US          100
# 262901      12      GB  317.7284362
# 265251       0      US            0
# 289847       5      US          220

# %%
df['name'].unique()
# Out:
# <StringArray>
# [                                        'The Songs of Adelaide & Abullah',
#                                                           'Where is Hank?',
#                        'ToshiCapital Rekordz Needs Help to Complete Album',
#               'Community Film Project: The Art of Neighborhood Filmmaking',
#                                                     'Monarch Espresso Bar',
#             'Support Solar Roasted Coffee & Green Energy!  SolarCoffee.co',
#                        'Chaser Strips. Our Strips make Shots their B*tch!',
#                    'SPIN - Premium Retractable In-Ear Headphones with Mic',
#                'STUDIO IN THE SKY - A Documentary Feature Film (Canceled)',
#                                                      'Of Jesus and Madmen',
#  ...
#                                               'Date Seat - Boston iOS App',
#                                                             'AT THE BEACH',
#                                              'Beach Wrestling Documentary',
#                                                                  'Islanda',
#                                               'Angela's Poetry (Canceled)',
#                        'ChknTruk Nationwide Charity Drive 2014 (Canceled)',
#                                                                'The Tribe',
#  'Walls of Remedy- New lesbian Romantic Comedy feature unlike any other!!',
#                                                 'BioDefense Education Kit',
#                                        'Nou Renmen Ayiti!  We Love Haiti!']
# Length: 321613, dtype: str

# %%
df[df['category'].isnull()]
# Out:
#                 ID                                               name  \
# 36671   1218074363                                        I am Rupert
# 41069    124438738                                     BlanketPals TM
# 63544   1378236004            {string&&loop} Knitting Craft with Code
# 96753   1574873938                         American Pin-up Revisitedd
# 269930   676846639  Uplift: The Wearable iPhone Case with Zipline&...
#
#        category       main_category      currency deadline  \
# 36671       NaN           Webseries  Film & Video      GBP
# 41069       NaN  Interactive Design        Design      USD
# 63544       NaN             Apparel       Fashion      USD
# 96753       NaN                 Art           Art      USD
# 269930      NaN              Design        Design      USD
#
#                        goal launched              pledged     state  \
# 36671   2014-05-16 22:25:57     2000  2014-03-27 21:25:57         5
# 41069   2015-03-25 20:51:48     9750  2015-02-23 21:51:48  10890.45
# 63544   2016-05-28 00:00:00     1800  2016-04-29 21:04:40      2308
# 96753   2014-04-03 17:52:09     7500  2014-03-04 17:52:09       100
# 269930  2011-04-04 20:08:17    50000  2011-03-05 20:08:17      1665
#
#            backers country usd_pledged
# 36671       failed       1          GB
# 41069   successful     107          US
# 63544   successful     119          US
# 96753       failed       1          US
# 269930    canceled      10          US

# %%
df['category'].unique()
# Out:
# <StringArray>
# [                            'Poetry',                     'Narrative Film',
#                               'Music',                       'Film & Video',
#                         'Restaurants',                               'Food',
#                              'Drinks',                     'Product Design',
#                         'Documentary',                         'Nonfiction',
#  ...
#              'float:left} (Canceled)',                 ' The Trip for Life',
#                   ' defying the odds', ' The store you've been looking for',
#                       ' Major Arcana',  ' MY LIFE IN THE MISSISSIPPI DELTA',
#                   ' so get on board!',                ' Head in the Clouds',
#                    ' Post Production',       ' a bike quest in New Zealand']
# Length: 771, dtype: str

# %%
df[df['main_category'] == 'Webseries']
# Out:
#                 ID                              name  \
# 36671   1218074363                       I am Rupert
# 65062   1387078972               Dateless The Series
# 152406  1905775245                       Music Today
# 168639  2003625595                Classic Automobile
# 200622   261815937  Pop Culture Purposed (a web show
# 230636   441511653        Couch2Kitchen Kids Edition
# 282496   752380461                    Depressed Girl
#
#                                            category main_category  \
# 36671                                           NaN     Webseries
# 65062                    Come be a part of the fun!     Webseries
# 152406                                The Making Of     Webseries
# 168639      designs innovations and inspirations.       Webseries
# 200622                        title tbd) (Canceled)     Webseries
# 230636             Off The Couch & Into The Kitchen     Webseries
# 282496   Changing the Way People See Mental Illness     Webseries
#
#             currency deadline                 goal launched  \
# 36671   Film & Video      GBP  2014-05-16 22:25:57     2000
# 65062   Film & Video      USD  2013-12-15 16:54:00     9200
# 152406  Film & Video      GBP  2016-11-27 21:02:43      110
# 168639  Film & Video      USD  2011-04-29 19:04:32    50000
# 200622  Film & Video      USD  2014-03-23 15:50:11    96100
# 230636  Film & Video      USD  2015-06-30 07:00:00    10130
# 282496  Film & Video      USD  2014-12-11 08:53:26      500
#
#                     pledged   state     backers country usd_pledged
# 36671   2014-03-27 21:25:57       5      failed       1          GB
# 65062   2013-11-15 16:54:00  9857.8  successful     150          US
# 152406  2016-10-28 21:02:43     110  successful      12          GB
# 168639  2011-03-30 19:04:32      25      failed       1          US
# 200622  2014-01-22 16:50:11     170    canceled       3          US
# 230636  2015-05-16 14:41:53    1665      failed      19          US
# 282496  2014-11-11 08:53:26     145      failed       3          US

# %%
df[df['usd_pledged'].isnull()]
# Out:
#                 ID                                               name  \
# 150     1000694855                      STREETFIGHTERZ WHEELIE MURICA
# 287      100149523                        Duncan Woods - Chameleon EP
# 549     1003023003          The Making of Ashley Kelley's Debut Album
# 561     1003130892                       Butter Side Down Debut Album
# 650     1003629045                            Chase Goehring debut EP
# ...            ...                                                ...
# 323391   997971307  EQUUS International Film Festival®, all-equine...
# 323456   998319149                            Emily 2050 - Short Film
# 323561     9988744                             Matthew Stephens Music
# 323683   999610349     Lady Vendredi: Afrofuturist concept 12 inch EP
# 323685   999621278                     Jeune auteur a besoin de vous!
#
#             category main_category currency             deadline  goal  \
# 150     Film & Video  Film & Video      USD  2014-09-20 06:59:00  6500
# 287            Music         Music      AUD  2015-08-25 23:00:00  4500
# 549            Music         Music      USD  2015-04-09 21:06:13  3500
# 561            Music         Music      USD  2015-11-26 10:59:00  6000
# 650            Music         Music      USD  2016-03-21 06:00:00  3000
# ...              ...           ...      ...                  ...   ...
# 323391  Film & Video  Film & Video      USD  2015-02-03 04:19:14  7500
# 323456  Film & Video  Film & Video      CAD  2014-05-23 00:30:09  3000
# 323561         Music         Music      USD  2016-02-05 23:00:00  5000
# 323683         Music         Music      GBP  2015-10-19 22:33:18  2000
# 323685    Publishing    Publishing      EUR  2015-11-20 21:28:13  1600
#
#                    launched  pledged      state backers country usd_pledged
# 150     2014-08-06 21:28:36      555  undefined       0    N,"0         NaN
# 287     2015-08-04 12:05:17     4767  undefined       0    N,"0         NaN
# 549     2015-03-10 20:06:13     3576  undefined       0    N,"0         NaN
# 561     2015-11-02 22:09:19   7007.8  undefined       0    N,"0         NaN
# 650     2016-02-23 03:09:49  3660.38  undefined       0    N,"0         NaN
# ...                     ...      ...        ...     ...     ...         ...
# 323391  2014-12-05 04:19:14       10  undefined       0    N,"0         NaN
# 323456  2014-04-08 00:30:09     3102  undefined       0    N,"0         NaN
# 323561  2016-01-06 21:59:23      235  undefined       0    N,"0         NaN
# 323683  2015-09-21 22:33:18     2125  undefined       0    N,"0         NaN
# 323685  2015-10-21 21:28:13        0  undefined       0    N,"0         NaN
#
# [3790 rows x 13 columns]

# %%
df['usd_pledged'].unique()
# Out:
# <StringArray>
# [            '0',           '220',             '1',          '1283',
#          '52375',          '1205',           '453',          '8233',
#        '6240.57',         '12700',
#  ...
#           '8935',         '42647',  '1673.7131361', '1937.69716526',
#        '13861.5',  '4814.8774787',  '4281.1485734',       '1732.02',
#  '5019.92088197',   '2698.974335']
# Length: 94377, dtype: str

# %%
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000004038                                     Where is Hank?
# 2       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3       1000011046  Community Film Project: The Art of Neighborhoo...
# 4       1000014025                               Monarch Espresso Bar
# ...            ...                                                ...
# 323745   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 323746   999977640                                          The Tribe
# 323747   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 323748   999987933                           BioDefense Education Kit
# 323749   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency             deadline   goal  \
# 0                Poetry    Publishing      GBP  2015-10-09 11:36:00   1000
# 1        Narrative Film  Film & Video      USD  2013-02-26 00:20:50  45000
# 2                 Music         Music      USD  2012-04-16 04:24:11   5000
# 3          Film & Video  Film & Video      USD  2015-08-29 01:00:00  19500
# 4           Restaurants          Food      USD  2016-04-01 13:38:27  50000
# ...                 ...           ...      ...                  ...    ...
# 323745      Documentary  Film & Video      USD  2014-10-17 02:35:30  50000
# 323746   Narrative Film  Film & Video      USD  2011-07-19 03:35:14   1500
# 323747   Narrative Film  Film & Video      USD  2010-08-16 05:59:00  15000
# 323748       Technology    Technology      USD  2016-02-13 02:00:00  15000
# 323749  Performance Art           Art      USD  2011-08-16 09:07:47   2000
#
#                    launched pledged       state backers country usd_pledged
# 0       2015-08-11 12:12:28       0      failed       0      GB           0
# 1       2013-01-12 00:20:50     220      failed       3      US         220
# 2       2012-03-17 03:24:11       1      failed       1      US           1
# 3       2015-07-04 08:35:03    1283    canceled      14      US        1283
# 4       2016-02-26 13:38:27   52375  successful     224      US       52375
# ...                     ...     ...         ...     ...     ...         ...
# 323745  2014-09-17 02:35:30      25    canceled       1      US          25
# 323746  2011-06-22 03:35:14     155      failed       5      US         155
# 323747  2010-07-01 19:40:30      20      failed       1      US          20
# 323748  2016-01-13 18:13:53     200      failed       6      US         200
# 323749  2011-07-19 09:07:47     524      failed      17      US         524
#
# [323750 rows x 13 columns]

# %%
engine = create_engine('mysql+pymysql://root:Hahaha!1!@localhost:3306/kickstarter')

# %%
df.to_sql(
  name = 'ks_projects',
  con = engine,
  if_exists = 'append',
  index = False
)
print('Successfully added and loaded to kickstarter db')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:197, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     190 def do_executemany(
#     191     self,
#     192     cursor: DBAPICursor,
#    (...)    195     context: Optional[ExecutionContext] = None,
#     196 ) -> None:
# --> 197     rowcount = cursor.executemany(statement, parameters)
#     198     if context is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:188, in Cursor.executemany(self, query, args)
#     187     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 188     return self._do_execute_many(
#     189         q_prefix,
#     190         q_values,
#     191         q_postfix,
#     192         args,
#     193         self.max_stmt_length,
#     194         self._get_db().encoding,
#     195     )
#     197 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:221, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     220 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 221     rows += self.execute(sql + postfix)
#     222     sql = bytearray(prefix)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:159, in Cursor.execute(self, query, args)
#     157 query = self.mogrify(query, args)
# --> 159 result = self._query(query)
#     160 self._executed = query
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:330, in Cursor._query(self, q)
#     329 self._clear_result()
# --> 330 conn.query(q)
#     331 self._do_get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:582, in Connection.query(self, sql, unbuffered)
#     581 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 582 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     583 return self._affected_rows
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:847, in Connection._read_query_result(self, unbuffered)
#     846 else:
# --> 847     result.read()
#     848 self._result = result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:1245, in MySQLResult.read(self)
#    1244 try:
# -> 1245     first_packet = self.connection._read_packet()
#    1247     if first_packet.is_ok_packet():
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:803, in Connection._read_packet(self, packet_type)
#     802         self._result.unbuffered_active = False
# --> 803     packet.raise_for_error()
#     804 return packet
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/err.py:154, in raise_mysql_exception(data)
#     153     errorclass = InternalError if errno < 1000 else OperationalError
# --> 154 raise errorclass(errno, errval, sqlstate=sqlstate)
#
# OperationalError: (1292, "Incorrect datetime value: 'SEK' for column 'deadline' at row 1455")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1421, in Connection.execute(self, statement, parameters, execution_options)
#    1420 else:
# -> 1421     return meth(
#    1422         self,
#    1423         distilled_parameters,
#    1424         execution_options or NO_OPTIONS,
#    1425     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1643, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1635 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1636     dialect=dialect,
#    1637     compiled_cache=compiled_cache,
#    (...)   1641     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1642 )
# -> 1643 ret = self._execute_context(
#    1644     dialect,
#    1645     dialect.execution_ctx_cls._init_compiled,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     execution_options,
#    1649     compiled_sql,
#    1650     distilled_parameters,
#    1651     elem,
#    1652     extracted_params,
#    1653     cache_hit=cache_hit,
#    1654 )
#    1655 if has_events:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2365, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2364     assert sqlalchemy_exception is not None
# -> 2365     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2366 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:197, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     190 def do_executemany(
#     191     self,
#     192     cursor: DBAPICursor,
#    (...)    195     context: Optional[ExecutionContext] = None,
#     196 ) -> None:
# --> 197     rowcount = cursor.executemany(statement, parameters)
#     198     if context is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:188, in Cursor.executemany(self, query, args)
#     187     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 188     return self._do_execute_many(
#     189         q_prefix,
#     190         q_values,
#     191         q_postfix,
#     192         args,
#     193         self.max_stmt_length,
#     194         self._get_db().encoding,
#     195     )
#     197 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:221, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     220 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 221     rows += self.execute(sql + postfix)
#     222     sql = bytearray(prefix)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:159, in Cursor.execute(self, query, args)
#     157 query = self.mogrify(query, args)
# --> 159 result = self._query(query)
#     160 self._executed = query
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/cursors.py:330, in Cursor._query(self, q)
#     329 self._clear_result()
# --> 330 conn.query(q)
#     331 self._do_get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:582, in Connection.query(self, sql, unbuffered)
#     581 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 582 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     583 return self._affected_rows
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:847, in Connection._read_query_result(self, unbuffered)
#     846 else:
# --> 847     result.read()
#     848 self._result = result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:1245, in MySQLResult.read(self)
#    1244 try:
# -> 1245     first_packet = self.connection._read_packet()
#    1247     if first_packet.is_ok_packet():
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/connections.py:803, in Connection._read_packet(self, packet_type)
#     802         self._result.unbuffered_active = False
# --> 803     packet.raise_for_error()
#     804 return packet
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pymysql/err.py:154, in raise_mysql_exception(data)
#     153     errorclass = InternalError if errno < 1000 else OperationalError
# --> 154 raise errorclass(errno, errval, sqlstate=sqlstate)
#
# OperationalError: (pymysql.err.OperationalError) (1292, "Incorrect datetime value: 'SEK' for column 'deadline' at row 1455")
# [SQL: INSERT INTO ks_projects (`ID`, name, category, main_category, currency, deadline, goal, launched, pledged, state, backers, country, usd_pledged) VALUES (%(ID)s, %(name)s, %(category)s, %(main_category)s, %(currency)s, %(deadline)s, %(goal)s, %(launched)s, %(pledged)s, %(state)s, %(backers)s, %(country)s, %(usd_pledged)s)]
# [parameters: [{'ID': 1000002330, 'name': 'The Songs of Adelaide & Abullah', 'category': 'Poetry', 'main_category': 'Publishing', 'currency': 'GBP', 'deadline': '2015-10-09 11:36:00', 'goal': '1000', 'launched': '2015-08-11 12:12:28', 'pledged': '0', 'state': 'failed', 'backers': '0', 'country': 'GB', 'usd_pledged': '0'}, {'ID': 1000004038, 'name': 'Where is Hank?', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': '2013-02-26 00:20:50', 'goal': '45000', 'launched': '2013-01-12 00:20:50', 'pledged': '220', 'state': 'failed', 'backers': '3', 'country': 'US', 'usd_pledged': '220'}, {'ID': 1000007540, 'name': 'ToshiCapital Rekordz Needs Help to Complete Album', 'category': 'Music', 'main_category': 'Music', 'currency': 'USD', 'deadline': '2012-04-16 04:24:11', 'goal': '5000', 'launched': '2012-03-17 03:24:11', 'pledged': '1', 'state': 'failed', 'backers': '1', 'country': 'US', 'usd_pledged': '1'}, {'ID': 1000011046, 'name': 'Community Film Project: The Art of Neighborhood Filmmaking', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': '2015-08-29 01:00:00', 'goal': '19500', 'launched': '2015-07-04 08:35:03', 'pledged': '1283', 'state': 'canceled', 'backers': '14', 'country': 'US', 'usd_pledged': '1283'}, {'ID': 1000014025, 'name': 'Monarch Espresso Bar', 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': '2016-04-01 13:38:27', 'goal': '50000', 'launched': '2016-02-26 13:38:27', 'pledged': '52375', 'state': 'successful', 'backers': '224', 'country': 'US', 'usd_pledged': '52375'}, {'ID': 1000023410, 'name': 'Support Solar Roasted Coffee & Green Energy!  SolarCoffee.co', 'category': 'Food', 'main_category': 'Food', 'currency': 'USD', 'deadline': '2014-12-21 18:30:44', 'goal': '1000', 'launched': '2014-12-01 18:30:44', 'pledged': '1205', 'state': 'successful', 'backers': '16', 'country': 'US', 'usd_pledged': '1205'}, {'ID': 1000030581, 'name': 'Chaser Strips. Our Strips make Shots their B*tch!', 'category': 'Drinks', 'main_category': 'Food', 'currency': 'USD', 'deadline': '2016-03-17 19:05:12', 'goal': '25000', 'launched': '2016-02-01 20:05:12', 'pledged': '453', 'state': 'failed', 'backers': '40', 'country': 'US', 'usd_pledged': '453'}, {'ID': 1000034518, 'name': 'SPIN - Premium Retractable In-Ear Headphones with Mic', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': '2014-05-29 18:14:43', 'goal': '125000', 'launched': '2014-04-24 18:14:43', 'pledged': '8233', 'state': 'canceled', 'backers': '58', 'country': 'US', 'usd_pledged': '8233'}  ... displaying 10 of 323750 total bound parameter sets ...  {'ID': 999987933, 'name': 'BioDefense Education Kit', 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': '2016-02-13 02:00:00', 'goal': '15000', 'launched': '2016-01-13 18:13:53', 'pledged': '200', 'state': 'failed', 'backers': '6', 'country': 'US', 'usd_pledged': '200'}, {'ID': 999988282, 'name': 'Nou Renmen Ayiti!  We Love Haiti!', 'category': 'Performance Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': '2011-08-16 09:07:47', 'goal': '2000', 'launched': '2011-07-19 09:07:47', 'pledged': '524', 'state': 'failed', 'backers': '17', 'country': 'US', 'usd_pledged': '524'}]]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.to_sql(
#       2   name = 'ks_projects',
#       3   con = engine,
#       4   if_exists = 'append',
#       5   index = False
#       6 )
#       7 print('Successfully added and loaded to kickstarter db')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2820 """
#    2821 Write records stored in a DataFrame to a SQL database.
#    2822
#    (...)   3048 3
#    3049 """  # noqa: E501
#    3050 from pandas.io import sql
# -> 3052 return sql.to_sql(
#    3053     self,
#    3054     name,
#    3055     con,
#    3056     schema=schema,
#    3057     if_exists=if_exists,
#    3058     index=index,
#    3059     index_label=index_label,
#    3060     chunksize=chunksize,
#    3061     dtype=dtype,
#    3062     method=method,
#    3063 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
#     840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#     844         if_exists=if_exists,
#     845         index=index,
#     846         index_label=index_label,
#     847         schema=schema,
#     848         chunksize=chunksize,
#     849         dtype=dtype,
#     850         method=method,
#     851         engine=engine,
#     852         **engine_kwargs,
#     853     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:2037, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2025 sql_engine = get_engine(engine)
#    2027 table = self.prep_table(
#    2028     frame=frame,
#    2029     name=name,
#    (...)   2034     dtype=dtype,
#    2035 )
# -> 2037 total_inserted = sql_engine.insert_records(
#    2038     table=table,
#    2039     con=self.con,
#    2040     frame=frame,
#    2041     name=name,
#    2042     index=index,
#    2043     schema=schema,
#    2044     chunksize=chunksize,
#    2045     method=method,
#    2046     **engine_kwargs,
#    2047 )
#    2049 self.check_case_sensitive(name=name, schema=schema)
#    2050 return total_inserted
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:1571, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1568 from sqlalchemy import exc
#    1570 try:
# -> 1571     return table.insert(chunksize=chunksize, method=method)
#    1572 except exc.StatementError as err:
#    1573     # GH34431
#    1574     # https://stackoverflow.com/a/67358288/6067848
#    1575     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1576     )|inf can not be used with MySQL"""
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:1122, in SQLTable.insert(self, chunksize, method)
#    1117     break
#    1119 chunk_iter = zip(
#    1120     *(arr[start_i:end_i] for arr in data_list), strict=True
#    1121 )
# -> 1122 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1123 # GH 46891
#    1124 if num_inserted is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:1014, in SQLTable._execute_insert(self, conn, keys, data_iter)
#    1002 """
#    1003 Execute SQL statement inserting data
#    1004
#    (...)   1011    Each item contains a list of values to be inserted
#    1012 """
#    1013 data = [dict(zip(keys, row, strict=True)) for row in data_iter]
# -> 1014 result = self.pd_sql.execute(self.table.insert(), data)
#    1015 return result.rowcount
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql 'INSERT INTO ks_projects ("ID", name, category, main_category, currency, deadline, goal, launched, pledged, state, backers, country, usd_pledged) VALUES (:ID, :name, :category, :main_category, :currency, :deadline, :goal, :launched, :pledged, :state, :backers, :country, :usd_pledged)': (pymysql.err.OperationalError) (1292, "Incorrect datetime value: 'SEK' for column 'deadline' at row 1455")
# [SQL: INSERT INTO ks_projects (`ID`, name, category, main_category, currency, deadline, goal, launched, pledged, state, backers, country, usd_pledged) VALUES (%(ID)s, %(name)s, %(category)s, %(main_category)s, %(currency)s, %(deadline)s, %(goal)s, %(launched)s, %(pledged)s, %(state)s, %(backers)s, %(country)s, %(usd_pledged)s)]
# [parameters: [{'ID': 1000002330, 'name': 'The Songs of Adelaide & Abullah', 'category': 'Poetry', 'main_category': 'Publishing', 'currency': 'GBP', 'deadline': '2015-10-09 11:36:00', 'goal': '1000', 'launched': '2015-08-11 12:12:28', 'pledged': '0', 'state': 'failed', 'backers': '0', 'country': 'GB', 'usd_pledged': '0'}, {'ID': 1000004038, 'name': 'Where is Hank?', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': '2013-02-26 00:20:50', 'goal': '45000', 'launched': '2013-01-12 00:20:50', 'pledged': '220', 'state': 'failed', 'backers': '3', 'country': 'US', 'usd_pledged': '220'}, {'ID': 1000007540, 'name': 'ToshiCapital Rekordz Needs Help to Complete Album', 'category': 'Music', 'main_category': 'Music', 'currency': 'USD', 'deadline': '2012-04-16 04:24:11', 'goal': '5000', 'launched': '2012-03-17 03:24:11', 'pledged': '1', 'state': 'failed', 'backers': '1', 'country': 'US', 'usd_pledged': '1'}, {'ID': 1000011046, 'name': 'Community Film Project: The Art of Neighborhood Filmmaking', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': '2015-08-29 01:00:00', 'goal': '19500', 'launched': '2015-07-04 08:35:03', 'pledged': '1283', 'state': 'canceled', 'backers': '14', 'country': 'US', 'usd_pledged': '1283'}, {'ID': 1000014025, 'name': 'Monarch Espresso Bar', 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': '2016-04-01 13:38:27', 'goal': '50000', 'launched': '2016-02-26 13:38:27', 'pledged': '52375', 'state': 'successful', 'backers': '224', 'country': 'US', 'usd_pledged': '52375'}, {'ID': 1000023410, 'name': 'Support Solar Roasted Coffee & Green Energy!  SolarCoffee.co', 'category': 'Food', 'main_category': 'Food', 'currency': 'USD', 'deadline': '2014-12-21 18:30:44', 'goal': '1000', 'launched': '2014-12-01 18:30:44', 'pledged': '1205', 'state': 'successful', 'backers': '16', 'country': 'US', 'usd_pledged': '1205'}, {'ID': 1000030581, 'name': 'Chaser Strips. Our Strips make Shots their B*tch!', 'category': 'Drinks', 'main_category': 'Food', 'currency': 'USD', 'deadline': '2016-03-17 19:05:12', 'goal': '25000', 'launched': '2016-02-01 20:05:12', 'pledged': '453', 'state': 'failed', 'backers': '40', 'country': 'US', 'usd_pledged': '453'}, {'ID': 1000034518, 'name': 'SPIN - Premium Retractable In-Ear Headphones with Mic', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': '2014-05-29 18:14:43', 'goal': '125000', 'launched': '2014-04-24 18:14:43', 'pledged': '8233', 'state': 'canceled', 'backers': '58', 'country': 'US', 'usd_pledged': '8233'}  ... displaying 10 of 323750 total bound parameter sets ...  {'ID': 999987933, 'name': 'BioDefense Education Kit', 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': '2016-02-13 02:00:00', 'goal': '15000', 'launched': '2016-01-13 18:13:53', 'pledged': '200', 'state': 'failed', 'backers': '6', 'country': 'US', 'usd_pledged': '200'}, {'ID': 999988282, 'name': 'Nou Renmen Ayiti!  We Love Haiti!', 'category': 'Performance Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': '2011-08-16 09:07:47', 'goal': '2000', 'launched': '2011-07-19 09:07:47', 'pledged': '524', 'state': 'failed', 'backers': '17', 'country': 'US', 'usd_pledged': '524'}]]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
sql_query = """
SELECT *
FROM ks_projects
LIMIT 20; """

# %%
df_all = pd.read_sql(sql_query, con=engine)
df_all
